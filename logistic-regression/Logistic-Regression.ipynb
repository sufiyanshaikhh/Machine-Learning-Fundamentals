# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# Implementing sigmoid function also known as logistic function from scratch. Also, exploring the routine of logistic regression.

# %%
# Importing dependencies
import numpy as np  # For scientific computation
import matplotlib.pyplot as plt  # For plotting data
from plt_one_addpt_onclick import plt_one_addpt_onclick
from lab_utils_common import draw_vthresh

# %% [markdown]
# For a classification task, we can start by using our linear regression model, to predict y given x. However, we would like the predictions of our classification model to be between 0 and 1 since our output variable y is either 0 or 1. This can be accomplished by using a "sigmoid function" which maps all input values to values between 0 and 1.

# %% [markdown]
# In the case of logistic regression, z (the input to the sigmoid function), is the output of a linear regression model. In the case of a single example, z is scalar. In the case of multiple examples, z may be a vector consisting of m values, one for each example. The implementation of the sigmoid function should cover both of these potential input formats.

# %%
# Implementing numpys exp method to calculation exponentials
# Input is an array. 
input_array = np.array([1,2,3])
exp_array = np.exp(input_array)

print("Input to exp:", input_array)
print("Output of exp:", exp_array)

# Input is a single number
input_val = 1  
exp_val = np.exp(input_val)

print("Input to exp:", input_val)
print("Output of exp:", exp_val)
# Out:
# Input to exp: [1 2 3]
# Output of exp: [ 2.72  7.39 20.09]
# Input to exp: 1
# Output of exp: 2.718281828459045

# %%
# Implementing sigmoid function
def sigmoid(z):
    """
    Compute the sigmoid of z

    Args:
        z (ndarray): A scalar, numpy array of any size.

    Returns:
        g (ndarray): sigmoid(z), with the same shape as z
         
    """

    g = 1/(1+np.exp(-z))
   
    return g

# %%
# Testing the sigmoid function
# Generate an array of evenly spaced values between -10 and 10
z_tmp = np.arange(-10,11)

# Use the function implemented above to get the sigmoid values
y = sigmoid(z_tmp)

# Code for pretty printing the two arrays next to each other
np.set_printoptions(precision=3) 
print("Input (z), Output (sigmoid(z))")
print(np.c_[z_tmp, y])
# Out:
# Input (z), Output (sigmoid(z))
# [[-1.000e+01  4.540e-05]
#  [-9.000e+00  1.234e-04]
#  [-8.000e+00  3.354e-04]
#  [-7.000e+00  9.111e-04]
#  [-6.000e+00  2.473e-03]
#  [-5.000e+00  6.693e-03]
#  [-4.000e+00  1.799e-02]
#  [-3.000e+00  4.743e-02]
#  [-2.000e+00  1.192e-01]
#  [-1.000e+00  2.689e-01]
#  [ 0.000e+00  5.000e-01]
#  [ 1.000e+00  7.311e-01]
#  [ 2.000e+00  8.808e-01]
#  [ 3.000e+00  9.526e-01]
#  [ 4.000e+00  9.820e-01]
#  [ 5.000e+00  9.933e-01]
#  [ 6.000e+00  9.975e-01]
#  [ 7.000e+00  9.991e-01]
#  [ 8.000e+00  9.997e-01]
#  [ 9.000e+00  9.999e-01]
#  [ 1.000e+01  1.000e+00]]

# %% [markdown]
# The values in the left column are z, and the values in the right column are sigmoid(z). As we can see, the input values to the sigmoid range from -10 to 10, and the output values range from 0 to 1.

# %%
# Plotting z vs sigmoid(z)
fig,ax = plt.subplots(1,1,figsize=(5,3))
ax.plot(z_tmp, y, c="b")

ax.set_title("Sigmoid function")
ax.set_ylabel('sigmoid(z)')
ax.set_xlabel('z')
draw_vthresh(ax,0)

# %% [markdown]
# As we can see, the sigmoid function approaches 0 as z goes to large negative values and approaches 1 as z goes to large positive values.

# %% [markdown]
# ## Exploring the Logistic Regression routine

# %% [markdown]
# The logistic regression at first finds the best fit curve to the training data. This is referred to as decision boundary in logistic regression. The equation for this decision boundary is evaluated and outputs as z. This z is the input to the sigmoid or logistic function that maps the output in the range of 0 to 1. A threshold of mainly 0.5 is toggled and the output of the sigmoid function is further evaluated to the threshold value to give the final prediction of the model.
